# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from random import randrange
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics import tsaplots

import statsmodels.api as sm
import numpy as np

# %%
df = pd.read_excel(r'C:\Users\treshanw\OneDrive - Star Garments\Datathon\timeseries.xlsx')

# %%
df
# Out:
#          date  median_income  population  real_estate_gdp  building_permits  \
# 0  2010-01-01          52504    1829.591          15629.0        430.219652
# 1  2011-01-01          55616    1840.914          16363.5        419.302428
# 2  2012-01-01          52196    1853.691          17956.6        556.637107
# 3  2013-01-01          57623    1865.813          18282.9        666.685258
# 4  2014-01-01          56870    1879.955          20602.0        637.692058
# 5  2015-01-01          60474    1892.059          22977.4        615.748070
# 6  2016-01-01          59374    1906.483          23483.0        693.165681
# 7  2017-01-01          59583    1916.998          26674.0        757.560607
# 8  2018-01-01          67575    1925.512          27117.7        684.095353
# 9  2019-01-01          73071    1932.571          28791.5        665.023746
# 10 2020-01-01          72024    1937.552          30561.3        773.105890
#
# ...

# %%
df.dtypes
df.drop(['Year'], axis=1)
# Out:
#    observation_date  median income  population(thousands)  \
# 0        2010-01-01   52504.000000            1829.591000
# 1        2011-01-01   55616.000000            1840.914000
# 2        2012-01-01   52196.000000            1853.691000
# 3        2013-01-01   57623.000000            1865.813000
# 4        2014-01-01   56870.000000            1879.955000
# 5        2015-01-01   60474.000000            1892.059000
# 6        2016-01-01   59374.000000            1906.483000
# 7        2017-01-01   59583.000000            1916.998000
# 8        2018-01-01   67575.000000            1925.512000
# 9        2019-01-01   73071.000000            1932.571000
# 10       2020-01-01   72024.000000            1937.552000
# 11       2021-01-01   72024.000000            1956.261239
# 12       2022-01-01   73170.734026            1967.638049
# 13       2023-01-01   75165.501480            1979.014860
# 14       2024-01-01   77160.268934            1990.391671
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df.columns

x = ['median income', 'population(thousands)',
       'gdp:real estate(mn)', 'building permits (no. of units) ', 'Total GPD',
       'Contribution of real estate towards gdp','Unemployment', 'Year']

# %%
x = df[x]
y = df['Customer count']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

lr=LinearRegression()
lr.fit(x_train, y_train)
y_pred=lr.predict(x_train)

print("Explained Variance:-",metrics.explained_variance_score(y_train, y_pred))
print("Max Error:-", metrics.max_error(y_train, y_pred))
print("Mean Absolute Error:-", metrics.mean_absolute_error(y_train, y_pred))
print("MSE:-", metrics.mean_squared_error(y_train, y_pred))
print("R-square Value:-", metrics.r2_score(y_train, y_pred))
# Out:
# Explained Variance:- 0.9811656413059748
# Max Error:- 892.036950423595
# Mean Absolute Error:- 169.043146288748
# MSE:- 109773.86810542266
# R-square Value:- 0.9811656413059748

# %%
import numpy as np
import pandas as pd

# We will use matplotlib to plot figures
import matplotlib.pyplot as plt

# For regression analysis we will use the statsmodels package
import statsmodels.formula.api as sm

# For visual inspection of the regression models
from statsmodels.graphics.regressionplots import plot_regress_exog, plot_fit, plot_leverage_resid2, influence_plot

# %%
m.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0db5d921a66f> in <module>
# ----> 1 m.summary()
#
# NameError: name 'm' is not defined

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

import numpy as np

import pandas

# %%
df.columns
# Out:
# Index(['date', 'median_income', 'population', 'real_estate_gdp',
#        'building_permits', 'total_gdp', 'contribution_to_wealth',
#        'customer_count', 'unemp', 'year'],
#       dtype='object')

# %%
x = ['median income', 'population(thousands)',
       'gdp:real estate(mn)', 'building permits (no. of units) ', 'Total GPD',
       'Contribution of real estate towards gdp', 'Unemployment', 'Year']
y = 'Customer count'

# %%
mod = smf.ols(formula='customer_count ~ median_income+population+real_estate_gdp+building_permits+total_gdp+contribution_to_wealth+unemp+year', data=df)

# %%
res = mod.fit()

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         customer_count   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                 -2.021
# Method:                 Least Squares   F-statistic:                    0.1637
# Date:                Wed, 13 Oct 2021   Prob (F-statistic):              0.975
# Time:                        16:18:32   Log-Likelihood:                -98.585
# No. Observations:                  11   AIC:                             215.2
# Df Residuals:                       2   BIC:                             218.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept              -2.522e+07   4.74e+07     -0.532      0.648   -2.29e+08    1.79e+08
# ...

# %%
mod = smf.ols(formula='customer_count ~ median_income+population+real_estate_gdp+building_permits+total_gdp+contribution_to_wealth+unemp', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         customer_count   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                 -0.076
# Method:                 Least Squares   F-statistic:                    0.2898
# Date:                Wed, 13 Oct 2021   Prob (F-statistic):              0.603
# Time:                        16:20:11   Log-Likelihood:                -101.18
# No. Observations:                  11   AIC:                             206.4
# Df Residuals:                       9   BIC:                             207.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        1.638e+04   3710.738      4.414      0.002    7985.610    2.48e+04
# ...

# %%
df2 = pd.read_excel(r'C:\Users\treshanw\OneDrive - Star Garments\Datathon\wells.xlsx')

# %%
mod = smf.ols(formula='customer_count ~ median_income+population+real_estate_gdp+building_permits+total_gdp+contribution_to_wealth+unemp+year', data=df2)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         customer_count   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                 -0.039
# Method:                 Least Squares   F-statistic:                    0.9533
# Date:                Wed, 13 Oct 2021   Prob (F-statistic):              0.606
# Time:                        16:26:01   Log-Likelihood:                -77.320
# No. Observations:                  11   AIC:                             172.6
# Df Residuals:                       2   BIC:                             176.2
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               7.807e+05   6.86e+06      0.114      0.920   -2.87e+07    3.03e+07
# ...
